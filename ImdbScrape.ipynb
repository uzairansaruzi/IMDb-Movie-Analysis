# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Load the existing dataset
file_path = 'box_office_data_1995_to_2024_with_generes.csv'
data = pd.read_csv(file_path)

# Headers to mimic a browser
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
}

# Function to fetch IMDb data
def fetch_imdb_data(title, year):
    try:
        print(f"Starting search for: {title} ({year})")

        # Search IMDb for the movie title and year
        search_query = f"{title} {year}"
        search_url = f"https://www.imdb.com/find?q={search_query.replace(' ', '+')}"
        print(f"Search URL: {search_url}")

        # Get search results page
        search_response = requests.get(search_url, headers=HEADERS)
        search_soup = BeautifulSoup(search_response.text, 'html.parser')
        print(f"Search page fetched successfully for {title}")

        # Get the first result link
        first_result = search_soup.select_one('li.ipc-metadata-list-summary-item a.ipc-metadata-list-summary-item__t')
        if not first_result or not first_result['href']:
            print(f"No search results found for {title}")
            return None, None, None

        movie_url = "https://www.imdb.com" + first_result['href']
        print(f"Navigated to movie page URL: {movie_url}")

        # Fetch the movie page
        movie_response = requests.get(movie_url, headers=HEADERS)
        movie_soup = BeautifulSoup(movie_response.text, 'html.parser')
        print(f"Movie page fetched successfully for {title}")

        # Scrape rating
        rating_element = movie_soup.find('span', class_='sc-d541859f-1 imUuxf')
        #print(f"Rating Element HTML: {rating_element}")
        rating = float(rating_element.text.strip()) if rating_element else None
        if rating is None:
            print(f"Rating not found for {title}")
        else:
            print(f"Rating found: {rating}")

        # Scrape director
        director_element = movie_soup.select_one('a.ipc-metadata-list-item__list-content-item--link[href*="/name/"]')
       # print(f"Director Element HTML: {director_element}")
        director = director_element.text.strip() if director_element else None
        if director is None:
            print(f"Director not found for {title}")
        else:
            print(f"Director found: {director}")

        # Scrape budget
        budget_element = movie_soup.select_one('[data-testid="title-boxoffice-budget"] .ipc-metadata-list-item__list-content-item')
       # print(f"Budget Element HTML: {budget_element}")
        budget = budget_element.text.strip() if budget_element else None
        if budget is None:
            print(f"Budget not found for {title}")
        else:
            print(f"Budget found: {budget}")

        return rating, budget, director

    except Exception as e:
        print(f"Error fetching data for {title}: {e}")
        return None, None, None

# Add IMDb data to all rows
ratings, budgets, directors = [], [], []

for _, row in data.iterrows():  # Process all rows
    title = row['Release']
    year = row['Year']
    print(f"\nFetching IMDb data for: {title} ({year})")
    rating, budget, director = fetch_imdb_data(title, year)
    ratings.append(rating)
    budgets.append(budget)
    directors.append(director)
  #  time.sleep(2)  # Respectful scraping delay

# Add the data to the dataframe
data['Rating'] = ratings
data['Budget'] = budgets
data['Director'] = directors

# Save the updated data
output_file = 'updated_box_office_data_full.csv'
data.to_csv(output_file, index=False)
print(f"Updated dataset saved to {output_file}")
# Out:
# Fetching IMDb data for: Inside Out 2 (2024)
# Starting search for: Inside Out 2 (2024)
# Search URL: https://www.imdb.com/find?q=Inside+Out+2+2024
# Search page fetched successfully for Inside Out 2
# Navigated to movie page URL: https://www.imdb.com/title/tt22022452/?ref_=fn_al_tt_1
# Movie page fetched successfully for Inside Out 2
# Rating found: 7.6
# Director found: Kelsey Mann
# Budget found: $200,000,000 (estimated)
#
# Fetching IMDb data for: Deadpool & Wolverine (2024)
# Starting search for: Deadpool & Wolverine (2024)
# Search URL: https://www.imdb.com/find?q=Deadpool+&+Wolverine+2024
# Search page fetched successfully for Deadpool & Wolverine
# Navigated to movie page URL: https://www.imdb.com/title/tt6263850/?ref_=fn_al_tt_1
# Movie page fetched successfully for Deadpool & Wolverine
# Rating found: 7.7
# Director found: Shawn Levy
# Budget found: $200,000,000 (estimated)
#
# Fetching IMDb data for: Despicable Me 4 (2024)
# Starting search for: Despicable Me 4 (2024)
# Search URL: https://www.imdb.com/find?q=Despicable+Me+4+2024
# Search page fetched successfully for Despicable Me 4
# Navigated to movie page URL: https://www.imdb.com/title/tt7510222/?ref_=fn_al_tt_1
# Movie page fetched successfully for Despicable Me 4
# Rating found: 6.2
# Director found: Chris Renaud
# Budget found: $100,000,000 (estimated)
#
# Fetching IMDb data for: Beetlejuice Beetlejuice (2024)
# Starting search for: Beetlejuice Beetlejuice (2024)
# Search URL: https://www.imdb.com/find?q=Beetlejuice+Beetlejuice+2024
# Search page fetched successfully for Beetlejuice Beetlejuice
# Navigated to movie page URL: https://www.imdb.com/title/tt2049403/?ref_=fn_al_tt_1
# Movie page fetched successfully for Beetlejuice Beetlejuice
# Rating found: 6.8
# Director found: Tim Burton
# Budget found: $100,000,000 (estimated)
#
# Fetching IMDb data for: Dune: Part Two (2024)
# Starting search for: Dune: Part Two (2024)
# Search URL: https://www.imdb.com/find?q=Dune:+Part+Two+2024
# Search page fetched successfully for Dune: Part Two
# Navigated to movie page URL: https://www.imdb.com/title/tt15239678/?ref_=fn_al_tt_1
# Movie page fetched successfully for Dune: Part Two
# Rating found: 8.5
# Director found: Denis Villeneuve
# Budget found: $190,000,000 (estimated)
#
# Fetching IMDb data for: Twisters (2024)
# Starting search for: Twisters (2024)
# Search URL: https://www.imdb.com/find?q=Twisters+2024
# Search page fetched successfully for Twisters
# Navigated to movie page URL: https://www.imdb.com/title/tt12584954/?ref_=fn_al_tt_1
# Movie page fetched successfully for Twisters
# Rating found: 6.5
# Director found: Lee Isaac Chung
# Budget found: $155,000,000 (estimated)
#
# Fetching IMDb data for: Godzilla x Kong: The New Empire (2024)
# Starting search for: Godzilla x Kong: The New Empire (2024)
# Search URL: https://www.imdb.com/find?q=Godzilla+x+Kong:+The+New+Empire+2024
# Search page fetched successfully for Godzilla x Kong: The New Empire
# Navigated to movie page URL: https://www.imdb.com/title/tt14539740/?ref_=fn_al_tt_1
# Movie page fetched successfully for Godzilla x Kong: The New Empire
# Rating found: 6.1
# Director found: Adam Wingard
# Budget found: $135,000,000 (estimated)
#
# Fetching IMDb data for: Kung Fu Panda 4 (2024)
# Starting search for: Kung Fu Panda 4 (2024)
# Search URL: https://www.imdb.com/find?q=Kung+Fu+Panda+4+2024
# Search page fetched successfully for Kung Fu Panda 4
# Navigated to movie page URL: https://www.imdb.com/title/tt21692408/?ref_=fn_al_tt_1
# Movie page fetched successfully for Kung Fu Panda 4
# Rating found: 6.3
# Director found: Mike Mitchell
# Budget found: $85,000,000 (estimated)
#
# Fetching IMDb data for: Bad Boys: Ride or Die (2024)
# Starting search for: Bad Boys: Ride or Die (2024)
# Search URL: https://www.imdb.com/find?q=Bad+Boys:+Ride+or+Die+2024
# Search page fetched successfully for Bad Boys: Ride or Die
# Navigated to movie page URL: https://www.imdb.com/title/tt4919268/?ref_=fn_al_tt_1
# Movie page fetched successfully for Bad Boys: Ride or Die
# Rating found: 6.6
# Director found: Adil El Arbi
# Budget found: $100,000,000 (estimated)
#
# Fetching IMDb data for: Kingdom of the Planet of the Apes (2024)
# Starting search for: Kingdom of the Planet of the Apes (2024)
# Search URL: https://www.imdb.com/find?q=Kingdom+of+the+Planet+of+the+Apes+2024
# Search page fetched successfully for Kingdom of the Planet of the Apes
# Navigated to movie page URL: https://www.imdb.com/title/tt11389872/?ref_=fn_al_tt_1
# Movie page fetched successfully for Kingdom of the Planet of the Apes
# Rating found: 6.9
# Director found: Wes Ball
# Budget found: $160,000,000 (estimated)
#
# Fetching IMDb data for: It Ends with Us (2024)
# Starting search for: It Ends with Us (2024)
# Search URL: https://www.imdb.com/find?q=It+Ends+with+Us+2024
# Search page fetched successfully for It Ends with Us
# Navigated to movie page URL: https://www.imdb.com/title/tt10655524/?ref_=fn_al_tt_1
# Movie page fetched successfully for It Ends with Us
# Rating found: 6.5
# Director found: Justin Baldoni
# Budget found: $25,000,000 (estimated)
#
# Fetching IMDb data for: The Wild Robot (2024)
# Starting search for: The Wild Robot (2024)
# Search URL: https://www.imdb.com/find?q=The+Wild+Robot+2024
# Search page fetched successfully for The Wild Robot
# Navigated to movie page URL: https://www.imdb.com/title/tt29623480/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Wild Robot
# Rating found: 8.3
# Director found: Chris Sanders
# Budget found: $78,000,000 (estimated)
#
# Fetching IMDb data for: A Quiet Place: Day One (2024)
# Starting search for: A Quiet Place: Day One (2024)
# Search URL: https://www.imdb.com/find?q=A+Quiet+Place:+Day+One+2024
# Search page fetched successfully for A Quiet Place: Day One
# Navigated to movie page URL: https://www.imdb.com/title/tt13433802/?ref_=fn_al_tt_1
# Movie page fetched successfully for A Quiet Place: Day One
# Rating found: 6.3
# Director found: Michael Sarnoski
# Budget found: $67,000,000 (estimated)
#
# Fetching IMDb data for: Venom: The Last Dance (2024)
# Starting search for: Venom: The Last Dance (2024)
# Search URL: https://www.imdb.com/find?q=Venom:+The+Last+Dance+2024
# Search page fetched successfully for Venom: The Last Dance
# Navigated to movie page URL: https://www.imdb.com/title/tt16366836/?ref_=fn_al_tt_1
# Movie page fetched successfully for Venom: The Last Dance
# Rating found: 6.2
# Director found: Kelly Marcel
# Budget found: $120,000,000 (estimated)
#
# Fetching IMDb data for: Wicked (2024)
# Starting search for: Wicked (2024)
# Search URL: https://www.imdb.com/find?q=Wicked+2024
# Search page fetched successfully for Wicked
# Navigated to movie page URL: https://www.imdb.com/title/tt1262426/?ref_=fn_al_tt_1
# Movie page fetched successfully for Wicked
# Rating found: 8.1
# Director found: Jon M. Chu
# Budget found: $150,000,000 (estimated)
#
# Fetching IMDb data for: Ghostbusters: Frozen Empire (2024)
# Starting search for: Ghostbusters: Frozen Empire (2024)
# Search URL: https://www.imdb.com/find?q=Ghostbusters:+Frozen+Empire+2024
# Search page fetched successfully for Ghostbusters: Frozen Empire
# Navigated to movie page URL: https://www.imdb.com/title/tt21235248/?ref_=fn_al_tt_1
# Movie page fetched successfully for Ghostbusters: Frozen Empire
# Rating found: 6.1
# Director found: Gil Kenan
# Budget found: $100,000,000 (estimated)
#
# Fetching IMDb data for: IF (2024)
# Starting search for: IF (2024)
# Search URL: https://www.imdb.com/find?q=IF+2024
# Search page fetched successfully for IF
# Navigated to movie page URL: https://www.imdb.com/title/tt11152168/?ref_=fn_al_tt_1
# Movie page fetched successfully for IF
# Rating found: 6.5
# Director found: John Krasinski
# Budget found: $110,000,000 (estimated)
#
# Fetching IMDb data for: Alien: Romulus (2024)
# Starting search for: Alien: Romulus (2024)
# Search URL: https://www.imdb.com/find?q=Alien:+Romulus+2024
# Search page fetched successfully for Alien: Romulus
# Navigated to movie page URL: https://www.imdb.com/title/tt18412256/?ref_=fn_al_tt_1
# Movie page fetched successfully for Alien: Romulus
# Rating found: 7.2
# Director found: Fede Alvarez
# Budget found: $80,000,000 (estimated)
#
# Fetching IMDb data for: Bob Marley: One Love (2024)
# Starting search for: Bob Marley: One Love (2024)
# Search URL: https://www.imdb.com/find?q=Bob+Marley:+One+Love+2024
# Search page fetched successfully for Bob Marley: One Love
# Navigated to movie page URL: https://www.imdb.com/title/tt8521778/?ref_=fn_al_tt_1
# Movie page fetched successfully for Bob Marley: One Love
# Rating found: 6.2
# Director found: Reinaldo Marcus Green
# Budget not found for Bob Marley: One Love
#
# Fetching IMDb data for: The Fall Guy (2024)
# Starting search for: The Fall Guy (2024)
# Search URL: https://www.imdb.com/find?q=The+Fall+Guy+2024
# Search page fetched successfully for The Fall Guy
# Navigated to movie page URL: https://www.imdb.com/title/tt1684562/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Fall Guy
# Rating found: 6.9
# Director found: David Leitch
# Budget found: $125,000,000 (estimated)
#
# Fetching IMDb data for: The Garfield Movie (2024)
# Starting search for: The Garfield Movie (2024)
# Search URL: https://www.imdb.com/find?q=The+Garfield+Movie+2024
# Search page fetched successfully for The Garfield Movie
# Navigated to movie page URL: https://www.imdb.com/title/tt5779228/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Garfield Movie
# Rating found: 5.7
# Director found: Mark Dindal
# Budget found: $60,000,000 (estimated)
#
# Fetching IMDb data for: Wonka (2024)
# Starting search for: Wonka (2024)
# Search URL: https://www.imdb.com/find?q=Wonka+2024
# Search page fetched successfully for Wonka
# Navigated to movie page URL: https://www.imdb.com/title/tt31805173/?ref_=fn_al_tt_1
# Movie page fetched successfully for Wonka
# Rating found: 5.7
# Director found: Timothée Chalamet
# Budget not found for Wonka
#
# Fetching IMDb data for: Longlegs (2024)
# Starting search for: Longlegs (2024)
# Search URL: https://www.imdb.com/find?q=Longlegs+2024
# Search page fetched successfully for Longlegs
# Navigated to movie page URL: https://www.imdb.com/title/tt23468450/?ref_=fn_al_tt_1
# Movie page fetched successfully for Longlegs
# Rating found: 6.7
# Director found: Osgood Perkins
# Budget not found for Longlegs
#
# Fetching IMDb data for: Migration (2024)
# Starting search for: Migration (2024)
# Search URL: https://www.imdb.com/find?q=Migration+2024
# Search page fetched successfully for Migration
# Navigated to movie page URL: https://www.imdb.com/title/tt32315156/?ref_=fn_al_tt_1
# Movie page fetched successfully for Migration
# Rating found: 5.5
# Director found: Joshua Philipp
# Budget found: $70,000 (estimated)
#
# Fetching IMDb data for: Mean Girls (2024)
# Starting search for: Mean Girls (2024)
# Search URL: https://www.imdb.com/find?q=Mean+Girls+2024
# Search page fetched successfully for Mean Girls
# Navigated to movie page URL: https://www.imdb.com/title/tt11762114/?ref_=fn_al_tt_1
# Movie page fetched successfully for Mean Girls
# Rating found: 5.6
# Director found: Samantha Jayne
# Budget found: $36,000,000 (estimated)
#
# Fetching IMDb data for: Civil War (2024)
# Starting search for: Civil War (2024)
# Search URL: https://www.imdb.com/find?q=Civil+War+2024
# Search page fetched successfully for Civil War
# Navigated to movie page URL: https://www.imdb.com/title/tt17279496/?ref_=fn_al_tt_1
# Movie page fetched successfully for Civil War
# Rating found: 7.0
# Director found: Alex Garland
# Budget found: $50,000,000 (estimated)
#
# Fetching IMDb data for: Smile 2 (2024)
# Starting search for: Smile 2 (2024)
# Search URL: https://www.imdb.com/find?q=Smile+2+2024
# Search page fetched successfully for Smile 2
# Navigated to movie page URL: https://www.imdb.com/title/tt29268110/?ref_=fn_al_tt_1
# Movie page fetched successfully for Smile 2
# Rating found: 6.9
# Director found: Parker Finn
# Budget found: $28,000,000 (estimated)
#
# Fetching IMDb data for: Furiosa: A Mad Max Saga (2024)
# Starting search for: Furiosa: A Mad Max Saga (2024)
# Search URL: https://www.imdb.com/find?q=Furiosa:+A+Mad+Max+Saga+2024
# Search page fetched successfully for Furiosa: A Mad Max Saga
# Navigated to movie page URL: https://www.imdb.com/title/tt12037194/?ref_=fn_al_tt_1
# Movie page fetched successfully for Furiosa: A Mad Max Saga
# Rating found: 7.5
# Director found: George Miller
# Budget found: $168,000,000 (estimated)
#
# Fetching IMDb data for: The Beekeeper (2024)
# Starting search for: The Beekeeper (2024)
# Search URL: https://www.imdb.com/find?q=The+Beekeeper+2024
# Search page fetched successfully for The Beekeeper
# Navigated to movie page URL: https://www.imdb.com/title/tt15314262/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Beekeeper
# Rating found: 6.3
# Director found: David Ayer
# Budget found: $40,000,000 (estimated)
#
# Fetching IMDb data for: Anyone But You (2024)
# Starting search for: Anyone But You (2024)
# Search URL: https://www.imdb.com/find?q=Anyone+But+You+2024
# Search page fetched successfully for Anyone But You
# Navigated to movie page URL: https://www.imdb.com/title/tt26047818/?ref_=fn_al_tt_1
# Movie page fetched successfully for Anyone But You
# Rating found: 6.1
# Director found: Will Gluck
# Budget found: $25,000,000 (estimated)
#
# Fetching IMDb data for: Transformers One (2024)
# Starting search for: Transformers One (2024)
# Search URL: https://www.imdb.com/find?q=Transformers+One+2024
# Search page fetched successfully for Transformers One
# Navigated to movie page URL: https://www.imdb.com/title/tt8864596/?ref_=fn_al_tt_1
# Movie page fetched successfully for Transformers One
# Rating found: 7.6
# Director found: Josh Cooley
# Budget found: $75,000,000 (estimated)
#
# Fetching IMDb data for: Joker: Folie à Deux (2024)
# Starting search for: Joker: Folie à Deux (2024)
# Search URL: https://www.imdb.com/find?q=Joker:+Folie+à+Deux+2024
# Search page fetched successfully for Joker: Folie à Deux
# Navigated to movie page URL: https://www.imdb.com/title/tt11315808/?ref_=fn_al_tt_1
# Movie page fetched successfully for Joker: Folie à Deux
# Rating found: 5.2
# Director found: Todd Phillips
# Budget found: $190,000,000 (estimated)
#
# Fetching IMDb data for: Gladiator II (2024)
# Starting search for: Gladiator II (2024)
# Search URL: https://www.imdb.com/find?q=Gladiator+II+2024
# Search page fetched successfully for Gladiator II
# Navigated to movie page URL: https://www.imdb.com/title/tt9218128/?ref_=fn_al_tt_1
# Movie page fetched successfully for Gladiator II
# Rating found: 6.9
# Director found: Ridley Scott
# Budget found: $250,000,000 (estimated)
#
# Fetching IMDb data for: Terrifier 3 (2024)
# Starting search for: Terrifier 3 (2024)
# Search URL: https://www.imdb.com/find?q=Terrifier+3+2024
# Search page fetched successfully for Terrifier 3
# Navigated to movie page URL: https://www.imdb.com/title/tt27911000/?ref_=fn_al_tt_1
# Movie page fetched successfully for Terrifier 3
# Rating found: 6.4
# Director found: Damien Leone
# Budget found: $2,000,000 (estimated)
#
# Fetching IMDb data for: Red One (2024)
# Starting search for: Red One (2024)
# Search URL: https://www.imdb.com/find?q=Red+One+2024
# Search page fetched successfully for Red One
# Navigated to movie page URL: https://www.imdb.com/title/tt14948432/?ref_=fn_al_tt_1
# Movie page fetched successfully for Red One
# Rating found: 6.9
# Director found: Jake Kasdan
# Budget found: $350,000,000 (estimated)
#
# Fetching IMDb data for: Challengers (2024)
# Starting search for: Challengers (2024)
# Search URL: https://www.imdb.com/find?q=Challengers+2024
# Search page fetched successfully for Challengers
# Navigated to movie page URL: https://www.imdb.com/title/tt16426418/?ref_=fn_al_tt_1
# Movie page fetched successfully for Challengers
# Rating found: 7.1
# Director found: Luca Guadagnino
# Budget found: $55,000,000 (estimated)
#
# Fetching IMDb data for: Aquaman and the Lost Kingdom (2024)
# Starting search for: Aquaman and the Lost Kingdom (2024)
# Search URL: https://www.imdb.com/find?q=Aquaman+and+the+Lost+Kingdom+2024
# Search page fetched successfully for Aquaman and the Lost Kingdom
# Navigated to movie page URL: https://www.imdb.com/title/tt9663764/?ref_=fn_al_tt_1
# Movie page fetched successfully for Aquaman and the Lost Kingdom
# Rating found: 5.6
# Director found: James Wan
# Budget found: $205,000,000 (estimated)
#
# Fetching IMDb data for: Argylle (2024)
# Starting search for: Argylle (2024)
# Search URL: https://www.imdb.com/find?q=Argylle+2024
# Search page fetched successfully for Argylle
# Navigated to movie page URL: https://www.imdb.com/title/tt15009428/?ref_=fn_al_tt_1
# Movie page fetched successfully for Argylle
# Rating found: 5.6
# Director found: Matthew Vaughn
# Budget found: $200,000,000 (estimated)
#
# Fetching IMDb data for: Madame Web (2024)
# Starting search for: Madame Web (2024)
# Search URL: https://www.imdb.com/find?q=Madame+Web+2024
# Search page fetched successfully for Madame Web
# Navigated to movie page URL: https://www.imdb.com/title/tt11057302/?ref_=fn_al_tt_1
# Movie page fetched successfully for Madame Web
# Rating found: 4.0
# Director found: S.J. Clarkson
# Budget found: $80,000,000 (estimated)
#
# Fetching IMDb data for: Trap (2024)
# Starting search for: Trap (2024)
# Search URL: https://www.imdb.com/find?q=Trap+2024
# Search page fetched successfully for Trap
# Navigated to movie page URL: https://www.imdb.com/title/tt26753003/?ref_=fn_al_tt_1
# Movie page fetched successfully for Trap
# Rating found: 5.9
# Director found: M. Night Shyamalan
# Budget found: $30,000,000 (estimated)
#
# Fetching IMDb data for: Speak No Evil (2024)
# Starting search for: Speak No Evil (2024)
# Search URL: https://www.imdb.com/find?q=Speak+No+Evil+2024
# Search page fetched successfully for Speak No Evil
# Navigated to movie page URL: https://www.imdb.com/title/tt27534307/?ref_=fn_al_tt_1
# Movie page fetched successfully for Speak No Evil
# Rating found: 6.9
# Director found: James Watkins
# Budget found: $15,000,000 (estimated)
#
# Fetching IMDb data for: The Strangers: Chapter 1 (2024)
# Starting search for: The Strangers: Chapter 1 (2024)
# Search URL: https://www.imdb.com/find?q=The+Strangers:+Chapter+1+2024
# Search page fetched successfully for The Strangers: Chapter 1
# Navigated to movie page URL: https://www.imdb.com/title/tt22050754/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Strangers: Chapter 1
# Rating found: 4.6
# Director found: Renny Harlin
# Budget found: $8,500,000 (estimated)
#
# Fetching IMDb data for: Coraline15th Anniversary (2024)
# Starting search for: Coraline15th Anniversary (2024)
# Search URL: https://www.imdb.com/find?q=Coraline15th+Anniversary+2024
# Search page fetched successfully for Coraline15th Anniversary
# Navigated to movie page URL: https://www.imdb.com/title/tt33972167/?ref_=fn_al_tt_1
# Movie page fetched successfully for Coraline15th Anniversary
# Rating not found for Coraline15th Anniversary
# Director not found for Coraline15th Anniversary
# Budget not found for Coraline15th Anniversary
#
# Fetching IMDb data for: Night Swim (2024)
# Starting search for: Night Swim (2024)
# Search URL: https://www.imdb.com/find?q=Night+Swim+2024
# Search page fetched successfully for Night Swim
# Navigated to movie page URL: https://www.imdb.com/title/tt9682428/?ref_=fn_al_tt_1
# Movie page fetched successfully for Night Swim
# Rating found: 4.7
# Director found: Bryce McGuire
# Budget found: $22,000,000 (estimated)
#
# Fetching IMDb data for: The Boys in the Boat (2024)
# Starting search for: The Boys in the Boat (2024)
# Search URL: https://www.imdb.com/find?q=The+Boys+in+the+Boat+2024
# Search page fetched successfully for The Boys in the Boat
# Navigated to movie page URL: https://www.imdb.com/title/tt34714450/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Boys in the Boat
# Rating not found for The Boys in the Boat
# Director not found for The Boys in the Boat
# Budget not found for The Boys in the Boat
#
# Fetching IMDb data for: Reagan (2024)
# Starting search for: Reagan (2024)
# Search URL: https://www.imdb.com/find?q=Reagan+2024
# Search page fetched successfully for Reagan
# Navigated to movie page URL: https://www.imdb.com/title/tt1723808/?ref_=fn_al_tt_1
# Movie page fetched successfully for Reagan
# Rating found: 6.2
# Director found: Sean McNamara
# Budget found: $25,000,000 (estimated)
#
# Fetching IMDb data for: The Forge (2024)
# Starting search for: The Forge (2024)
# Search URL: https://www.imdb.com/find?q=The+Forge+2024
# Search page fetched successfully for The Forge
# Navigated to movie page URL: https://www.imdb.com/title/tt26731216/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Forge
# Rating found: 6.4
# Director found: Alex Kendrick
# Budget not found for The Forge
#
# Fetching IMDb data for: Horizon: An American Saga - Chapter 1 (2024)
# Starting search for: Horizon: An American Saga - Chapter 1 (2024)
# Search URL: https://www.imdb.com/find?q=Horizon:+An+American+Saga+-+Chapter+1+2024
# Search page fetched successfully for Horizon: An American Saga - Chapter 1
# Navigated to movie page URL: https://www.imdb.com/title/tt17505010/?ref_=fn_al_tt_1
# Movie page fetched successfully for Horizon: An American Saga - Chapter 1
# Rating found: 6.7
# Director found: Kevin Costner
# Budget found: $100,000,000 (estimated)
#
# Fetching IMDb data for: Conclave (2024)
# Starting search for: Conclave (2024)
# Search URL: https://www.imdb.com/find?q=Conclave+2024
# Search page fetched successfully for Conclave
# Navigated to movie page URL: https://www.imdb.com/title/tt20215234/?ref_=fn_al_tt_1
# Movie page fetched successfully for Conclave
# Rating found: 7.5
# Director found: Edward Berger
# Budget found: $20,000,000 (estimated)
#
# Fetching IMDb data for: Imaginary (2024)
# Starting search for: Imaginary (2024)
# Search URL: https://www.imdb.com/find?q=Imaginary+2024
# Search page fetched successfully for Imaginary
# Navigated to movie page URL: https://www.imdb.com/title/tt26658104/?ref_=fn_al_tt_1
# Movie page fetched successfully for Imaginary
# Rating found: 4.7
# Director found: Jeff Wadlow
# Budget found: $13,000,000 (estimated)
#
# Fetching IMDb data for: Abigail (2024)
# Starting search for: Abigail (2024)
# Search URL: https://www.imdb.com/find?q=Abigail+2024
# Search page fetched successfully for Abigail
# Navigated to movie page URL: https://www.imdb.com/title/tt27489557/?ref_=fn_al_tt_1
# Movie page fetched successfully for Abigail
# Rating found: 6.6
# Director found: Matt Bettinelli-Olpin
# Budget found: $28,000,000 (estimated)
#
# Fetching IMDb data for: The Best Christmas Pageant Ever (2024)
# Starting search for: The Best Christmas Pageant Ever (2024)
# Search URL: https://www.imdb.com/find?q=The+Best+Christmas+Pageant+Ever+2024
# Search page fetched successfully for The Best Christmas Pageant Ever
# Navigated to movie page URL: https://www.imdb.com/title/tt2347285/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Best Christmas Pageant Ever
# Rating found: 7.3
# Director found: Dallas Jenkins
# Budget found: $20,000,000 (estimated)
#
# Fetching IMDb data for: Monkey Man (2024)
# Starting search for: Monkey Man (2024)
# Search URL: https://www.imdb.com/find?q=Monkey+Man+2024
# Search page fetched successfully for Monkey Man
# Navigated to movie page URL: https://www.imdb.com/title/tt9214772/?ref_=fn_al_tt_1
# Movie page fetched successfully for Monkey Man
# Rating found: 6.8
# Director found: Dev Patel
# Budget found: $10,000,000 (estimated)
#
# Fetching IMDb data for: Arthur the King (2024)
# Starting search for: Arthur the King (2024)
# Search URL: https://www.imdb.com/find?q=Arthur+the+King+2024
# Search page fetched successfully for Arthur the King
# Navigated to movie page URL: https://www.imdb.com/title/tt10720352/?ref_=fn_al_tt_1
# Movie page fetched successfully for Arthur the King
# Rating found: 7.0
# Director found: Simon Cellan Jones
# Budget not found for Arthur the King
#
# Fetching IMDb data for: Heretic (2024)
# Starting search for: Heretic (2024)
# Search URL: https://www.imdb.com/find?q=Heretic+2024
# Search page fetched successfully for Heretic
# Navigated to movie page URL: https://www.imdb.com/title/tt28015403/?ref_=fn_al_tt_1
# Movie page fetched successfully for Heretic
# Rating found: 7.2
# Director found: Scott Beck
# Budget not found for Heretic
#
# Fetching IMDb data for: We Live in Time (2024)
# Starting search for: We Live in Time (2024)
# Search URL: https://www.imdb.com/find?q=We+Live+in+Time+2024
# Search page fetched successfully for We Live in Time
# Navigated to movie page URL: https://www.imdb.com/title/tt27131358/?ref_=fn_al_tt_1
# Movie page fetched successfully for We Live in Time
# Rating found: 7.1
# Director found: John Crowley
# Budget not found for We Live in Time
#
# Fetching IMDb data for: Poor Things (2024)
# Starting search for: Poor Things (2024)
# Search URL: https://www.imdb.com/find?q=Poor+Things+2024
# Search page fetched successfully for Poor Things
# Navigated to movie page URL: https://www.imdb.com/title/tt32460365/?ref_=fn_al_tt_1
# Movie page fetched successfully for Poor Things
# Rating not found for Poor Things
# Director not found for Poor Things
# Budget not found for Poor Things
#
# Fetching IMDb data for: Blink Twice (2024)
# Starting search for: Blink Twice (2024)
# Search URL: https://www.imdb.com/find?q=Blink+Twice+2024
# Search page fetched successfully for Blink Twice
# Navigated to movie page URL: https://www.imdb.com/title/tt14858658/?ref_=fn_al_tt_1
# Movie page fetched successfully for Blink Twice
# Rating found: 6.5
# Director found: Zoë Kravitz
# Budget found: $20,000,000 (estimated)
#
# Fetching IMDb data for: The Bikeriders (2024)
# Starting search for: The Bikeriders (2024)
# Search URL: https://www.imdb.com/find?q=The+Bikeriders+2024
# Search page fetched successfully for The Bikeriders
# Navigated to movie page URL: https://www.imdb.com/title/tt21454134/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Bikeriders
# Rating found: 6.7
# Director found: Jeff Nichols
# Budget found: $40,000,000 (estimated)
#
# Fetching IMDb data for: The Ministry of Ungentlemanly Warfare (2024)
# Starting search for: The Ministry of Ungentlemanly Warfare (2024)
# Search URL: https://www.imdb.com/find?q=The+Ministry+of+Ungentlemanly+Warfare+2024
# Search page fetched successfully for The Ministry of Ungentlemanly Warfare
# Navigated to movie page URL: https://www.imdb.com/title/tt5177120/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Ministry of Ungentlemanly Warfare
# Rating found: 6.8
# Director found: Guy Ritchie
# Budget found: $60,000,000 (estimated)
#
# Fetching IMDb data for: Fly Me to the Moon (2024)
# Starting search for: Fly Me to the Moon (2024)
# Search URL: https://www.imdb.com/find?q=Fly+Me+to+the+Moon+2024
# Search page fetched successfully for Fly Me to the Moon
# Navigated to movie page URL: https://www.imdb.com/title/tt1896747/?ref_=fn_al_tt_1
# Movie page fetched successfully for Fly Me to the Moon
# Rating found: 6.6
# Director found: Greg Berlanti
# Budget found: $100,000,000 (estimated)
#
# Fetching IMDb data for: Unsung Hero (2024)
# Starting search for: Unsung Hero (2024)
# Search URL: https://www.imdb.com/find?q=Unsung+Hero+2024
# Search page fetched successfully for Unsung Hero
# Navigated to movie page URL: https://www.imdb.com/title/tt23638614/?ref_=fn_al_tt_1
# Movie page fetched successfully for Unsung Hero
# Rating found: 7.0
# Director found: Richard L. Ramsey
# Budget found: $6,000,000 (estimated)
#
# Fetching IMDb data for: The First Omen (2024)
# Starting search for: The First Omen (2024)
# Search URL: https://www.imdb.com/find?q=The+First+Omen+2024
# Search page fetched successfully for The First Omen
# Navigated to movie page URL: https://www.imdb.com/title/tt5672290/?ref_=fn_al_tt_1
# Movie page fetched successfully for The First Omen
# Rating found: 6.5
# Director found: Arkasha Stevenson
# Budget found: $30,000,000 (estimated)
#
# Fetching IMDb data for: Cabrini (2024)
# Starting search for: Cabrini (2024)
# Search URL: https://www.imdb.com/find?q=Cabrini+2024
# Search page fetched successfully for Cabrini
# Navigated to movie page URL: https://www.imdb.com/title/tt14351082/?ref_=fn_al_tt_1
# Movie page fetched successfully for Cabrini
# Rating found: 7.3
# Director found: Alejandro Monteverde
# Budget found: $34,000,000 (estimated)
#
# Fetching IMDb data for: American Fiction (2024)
# Starting search for: American Fiction (2024)
# Search URL: https://www.imdb.com/find?q=American+Fiction+2024
# Search page fetched successfully for American Fiction
# Navigated to movie page URL: https://www.imdb.com/title/tt32126583/?ref_=fn_al_tt_1
# Movie page fetched successfully for American Fiction
# Rating not found for American Fiction
# Director found: Mark W. Curran
# Budget not found for American Fiction
#
# Fetching IMDb data for: Ordinary Angels (2024)
# Starting search for: Ordinary Angels (2024)
# Search URL: https://www.imdb.com/find?q=Ordinary+Angels+2024
# Search page fetched successfully for Ordinary Angels
# Navigated to movie page URL: https://www.imdb.com/title/tt4996328/?ref_=fn_al_tt_1
# Movie page fetched successfully for Ordinary Angels
# Rating found: 7.4
# Director found: Jon Gunn
# Budget found: $13,000,000 (estimated)
#
# Fetching IMDb data for: The Iron Claw (2024)
# Starting search for: The Iron Claw (2024)
# Search URL: https://www.imdb.com/find?q=The+Iron+Claw+2024
# Search page fetched successfully for The Iron Claw
# Navigated to movie page URL: https://www.imdb.com/title/tt21064584/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Iron Claw
# Rating found: 7.6
# Director found: Sean Durkin
# Budget found: $15,000,000 (estimated)
#
# Fetching IMDb data for: The Watchers (2024)
# Starting search for: The Watchers (2024)
# Search URL: https://www.imdb.com/find?q=The+Watchers+2024
# Search page fetched successfully for The Watchers
# Navigated to movie page URL: https://www.imdb.com/title/tt26736843/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Watchers
# Rating found: 5.7
# Director found: Ishana Shyamalan
# Budget not found for The Watchers
#
# Fetching IMDb data for: Tarot (2024)
# Starting search for: Tarot (2024)
# Search URL: https://www.imdb.com/find?q=Tarot+2024
# Search page fetched successfully for Tarot
# Navigated to movie page URL: https://www.imdb.com/title/tt14088510/?ref_=fn_al_tt_1
# Movie page fetched successfully for Tarot
# Rating found: 4.8
# Director found: Spenser Cohen
# Budget found: $8,250,000 (estimated)
#
# Fetching IMDb data for: Demon Slayer: Kimetsu No Yaiba - To the Hashira Training (2024)
# Starting search for: Demon Slayer: Kimetsu No Yaiba - To the Hashira Training (2024)
# Search URL: https://www.imdb.com/find?q=Demon+Slayer:+Kimetsu+No+Yaiba+-+To+the+Hashira+Training+2024
# Search page fetched successfully for Demon Slayer: Kimetsu No Yaiba - To the Hashira Training
# Navigated to movie page URL: https://www.imdb.com/title/tt30395619/?ref_=fn_al_tt_1
# Movie page fetched successfully for Demon Slayer: Kimetsu No Yaiba - To the Hashira Training
# Rating found: 7.1
# Director found: Haruo Sotozaki
# Budget not found for Demon Slayer: Kimetsu No Yaiba - To the Hashira Training
#
# Fetching IMDb data for: Harold and the Purple Crayon (2024)
# Starting search for: Harold and the Purple Crayon (2024)
# Search URL: https://www.imdb.com/find?q=Harold+and+the+Purple+Crayon+2024
# Search page fetched successfully for Harold and the Purple Crayon
# Navigated to movie page URL: https://www.imdb.com/title/tt1609486/?ref_=fn_al_tt_1
# Movie page fetched successfully for Harold and the Purple Crayon
# Rating found: 5.7
# Director found: Carlos Saldanha
# Budget found: $40,000,000 (estimated)
#
# Fetching IMDb data for: The Color Purple (2024)
# Starting search for: The Color Purple (2024)
# Search URL: https://www.imdb.com/find?q=The+Color+Purple+2024
# Search page fetched successfully for The Color Purple
# Navigated to movie page URL: https://www.imdb.com/title/tt1200263/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Color Purple
# Rating found: 6.8
# Director found: Blitz Bazawule
# Budget found: $100,000,000 (estimated)
#
# Fetching IMDb data for: The Substance (2024)
# Starting search for: The Substance (2024)
# Search URL: https://www.imdb.com/find?q=The+Substance+2024
# Search page fetched successfully for The Substance
# Navigated to movie page URL: https://www.imdb.com/title/tt17526714/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Substance
# Rating found: 7.4
# Director found: Coralie Fargeat
# Budget found: $17,500,000 (estimated)
#
# Fetching IMDb data for: Immaculate (2024)
# Starting search for: Immaculate (2024)
# Search URL: https://www.imdb.com/find?q=Immaculate+2024
# Search page fetched successfully for Immaculate
# Navigated to movie page URL: https://www.imdb.com/title/tt23137390/?ref_=fn_al_tt_1
# Movie page fetched successfully for Immaculate
# Rating found: 5.8
# Director found: Michael Mohan
# Budget found: $9,000,000 (estimated)
#
# Fetching IMDb data for: Borderlands (2024)
# Starting search for: Borderlands (2024)
# Search URL: https://www.imdb.com/find?q=Borderlands+2024
# Search page fetched successfully for Borderlands
# Navigated to movie page URL: https://www.imdb.com/title/tt4978420/?ref_=fn_al_tt_1
# Movie page fetched successfully for Borderlands
# Rating found: 4.6
# Director found: Eli Roth
# Budget found: $115,000,000 (estimated)
#
# Fetching IMDb data for: MaXXXine (2024)
# Starting search for: MaXXXine (2024)
# Search URL: https://www.imdb.com/find?q=MaXXXine+2024
# Search page fetched successfully for MaXXXine
# Navigated to movie page URL: https://www.imdb.com/title/tt22048412/?ref_=fn_al_tt_1
# Movie page fetched successfully for MaXXXine
# Rating found: 6.3
# Director found: Ti West
# Budget found: $1,000,000 (estimated)
#
# Fetching IMDb data for: The Chosen: S4 Episodes 1-3 (2024)
# Starting search for: The Chosen: S4 Episodes 1-3 (2024)
# Search URL: https://www.imdb.com/find?q=The+Chosen:+S4+Episodes+1-3+2024
# Search page fetched successfully for The Chosen: S4 Episodes 1-3
# Navigated to movie page URL: https://www.imdb.com/title/tt31513720/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Chosen: S4 Episodes 1-3
# Rating not found for The Chosen: S4 Episodes 1-3
# Director found: Ian Graham
# Budget not found for The Chosen: S4 Episodes 1-3
#
# Fetching IMDb data for: Star Wars: Episode I - The Phantom Menace2024 Re-release (2024)
# Starting search for: Star Wars: Episode I - The Phantom Menace2024 Re-release (2024)
# Search URL: https://www.imdb.com/find?q=Star+Wars:+Episode+I+-+The+Phantom+Menace2024+Re-release+2024
# Search page fetched successfully for Star Wars: Episode I - The Phantom Menace2024 Re-release
# Navigated to movie page URL: https://www.imdb.com/title/tt31540742/?ref_=fn_al_tt_1
# Movie page fetched successfully for Star Wars: Episode I - The Phantom Menace2024 Re-release
# Rating found: 6.4
# Director found: Spencer Gilbert
# Budget not found for Star Wars: Episode I - The Phantom Menace2024 Re-release
#
# Fetching IMDb data for: Kalki 2898 AD (2024)
# Starting search for: Kalki 2898 AD (2024)
# Search URL: https://www.imdb.com/find?q=Kalki+2898+AD+2024
# Search page fetched successfully for Kalki 2898 AD
# Navigated to movie page URL: https://www.imdb.com/title/tt12735488/?ref_=fn_al_tt_1
# Movie page fetched successfully for Kalki 2898 AD
# Rating found: 7.0
# Director found: Nag Ashwin
# Budget found: ₹6,000,000,000 (estimated)
#
# Fetching IMDb data for: Am I Racist? (2024)
# Starting search for: Am I Racist? (2024)
# Search URL: https://www.imdb.com/find?q=Am+I+Racist?+2024
# Search page fetched successfully for Am I Racist?
# Navigated to movie page URL: https://www.imdb.com/title/tt33034103/?ref_=fn_al_tt_1
# Movie page fetched successfully for Am I Racist?
# Rating found: 6.7
# Director found: Justin Folk
# Budget not found for Am I Racist?
#
# Fetching IMDb data for: Here (2024)
# Starting search for: Here (2024)
# Search URL: https://www.imdb.com/find?q=Here+2024
# Search page fetched successfully for Here
# Navigated to movie page URL: https://www.imdb.com/title/tt18272208/?ref_=fn_al_tt_1
# Movie page fetched successfully for Here
# Rating found: 6.2
# Director found: Robert Zemeckis
# Budget found: $45,000,000 (estimated)
#
# Fetching IMDb data for: Anora (2024)
# Starting search for: Anora (2024)
# Search URL: https://www.imdb.com/find?q=Anora+2024
# Search page fetched successfully for Anora
# Navigated to movie page URL: https://www.imdb.com/title/tt28607951/?ref_=fn_al_tt_1
# Movie page fetched successfully for Anora
# Rating found: 8.2
# Director found: Sean Baker
# Budget not found for Anora
#
# Fetching IMDb data for: Sound of Hope: The Story of Possum Trot (2024)
# Starting search for: Sound of Hope: The Story of Possum Trot (2024)
# Search URL: https://www.imdb.com/find?q=Sound+of+Hope:+The+Story+of+Possum+Trot+2024
# Search page fetched successfully for Sound of Hope: The Story of Possum Trot
# Navigated to movie page URL: https://www.imdb.com/title/tt6881490/?ref_=fn_al_tt_1
# Movie page fetched successfully for Sound of Hope: The Story of Possum Trot
# Rating found: 7.1
# Director found: Joshua Weigel
# Budget not found for Sound of Hope: The Story of Possum Trot
#
# Fetching IMDb data for: Godzilla Minus One (2024)
# Starting search for: Godzilla Minus One (2024)
# Search URL: https://www.imdb.com/find?q=Godzilla+Minus+One+2024
# Search page fetched successfully for Godzilla Minus One
# Navigated to movie page URL: https://www.imdb.com/title/tt23289160/?ref_=fn_al_tt_1
# Movie page fetched successfully for Godzilla Minus One
# Rating found: 7.7
# Director found: Takashi Yamazaki
# Budget found: $15,000,000 (estimated)
#
# Fetching IMDb data for: The Boy and the Heron (2024)
# Starting search for: The Boy and the Heron (2024)
# Search URL: https://www.imdb.com/find?q=The+Boy+and+the+Heron+2024
# Search page fetched successfully for The Boy and the Heron
# Navigated to movie page URL: https://www.imdb.com/title/tt6587046/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Boy and the Heron
# Rating found: 7.4
# Director found: Hayao Miyazaki
# Budget not found for The Boy and the Heron
#
# Fetching IMDb data for: The Chosen: S4 Episodes 4-6 (2024)
# Starting search for: The Chosen: S4 Episodes 4-6 (2024)
# Search URL: https://www.imdb.com/find?q=The+Chosen:+S4+Episodes+4-6+2024
# Search page fetched successfully for The Chosen: S4 Episodes 4-6
# Navigated to movie page URL: https://www.imdb.com/title/tt33908830/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Chosen: S4 Episodes 4-6
# Rating not found for The Chosen: S4 Episodes 4-6
# Director not found for The Chosen: S4 Episodes 4-6
# Budget not found for The Chosen: S4 Episodes 4-6
#
# Fetching IMDb data for: Never Let Go (2024)
# Starting search for: Never Let Go (2024)
# Search URL: https://www.imdb.com/find?q=Never+Let+Go+2024
# Search page fetched successfully for Never Let Go
# Navigated to movie page URL: https://www.imdb.com/title/tt14415204/?ref_=fn_al_tt_1
# Movie page fetched successfully for Never Let Go
# Rating found: 5.5
# Director found: Alexandre Aja
# Budget found: $25,000,000 (estimated)
#
# Fetching IMDb data for: Late Night with the Devil (2024)
# Starting search for: Late Night with the Devil (2024)
# Search URL: https://www.imdb.com/find?q=Late+Night+with+the+Devil+2024
# Search page fetched successfully for Late Night with the Devil
# Navigated to movie page URL: https://www.imdb.com/title/tt14966898/?ref_=fn_al_tt_1
# Movie page fetched successfully for Late Night with the Devil
# Rating found: 7.0
# Director found: Cameron Cairnes
# Budget not found for Late Night with the Devil
#
# Fetching IMDb data for: Lisa Frankenstein (2024)
# Starting search for: Lisa Frankenstein (2024)
# Search URL: https://www.imdb.com/find?q=Lisa+Frankenstein+2024
# Search page fetched successfully for Lisa Frankenstein
# Navigated to movie page URL: https://www.imdb.com/title/tt21188080/?ref_=fn_al_tt_1
# Movie page fetched successfully for Lisa Frankenstein
# Rating found: 6.1
# Director found: Zelda Williams
# Budget found: $13,000,000 (estimated)
#
# Fetching IMDb data for: Piece by Piece (2024)
# Starting search for: Piece by Piece (2024)
# Search URL: https://www.imdb.com/find?q=Piece+by+Piece+2024
# Search page fetched successfully for Piece by Piece
# Navigated to movie page URL: https://www.imdb.com/title/tt31064841/?ref_=fn_al_tt_1
# Movie page fetched successfully for Piece by Piece
# Rating found: 6.9
# Director found: Morgan Neville
# Budget not found for Piece by Piece
#
# Fetching IMDb data for: Saturday Night (2024)
# Starting search for: Saturday Night (2024)
# Search URL: https://www.imdb.com/find?q=Saturday+Night+2024
# Search page fetched successfully for Saturday Night
# Navigated to movie page URL: https://www.imdb.com/title/tt27657135/?ref_=fn_al_tt_1
# Movie page fetched successfully for Saturday Night
# Rating found: 7.1
# Director found: Jason Reitman
# Budget not found for Saturday Night
#
# Fetching IMDb data for: The Crow (2024)
# Starting search for: The Crow (2024)
# Search URL: https://www.imdb.com/find?q=The+Crow+2024
# Search page fetched successfully for The Crow
# Navigated to movie page URL: https://www.imdb.com/title/tt1340094/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Crow
# Rating found: 4.7
# Director found: Rupert Sanders
# Budget found: $50,000,000 (estimated)
#
# Fetching IMDb data for: Thelma (2024)
# Starting search for: Thelma (2024)
# Search URL: https://www.imdb.com/find?q=Thelma+2024
# Search page fetched successfully for Thelma
# Navigated to movie page URL: https://www.imdb.com/title/tt23778968/?ref_=fn_al_tt_1
# Movie page fetched successfully for Thelma
# Rating found: 7.0
# Director found: Josh Margolin
# Budget not found for Thelma
#
# Fetching IMDb data for: Love Lies Bleeding (2024)
# Starting search for: Love Lies Bleeding (2024)
# Search URL: https://www.imdb.com/find?q=Love+Lies+Bleeding+2024
# Search page fetched successfully for Love Lies Bleeding
# Navigated to movie page URL: https://www.imdb.com/title/tt19637052/?ref_=fn_al_tt_1
# Movie page fetched successfully for Love Lies Bleeding
# Rating found: 6.7
# Director found: Rose Glass
# Budget not found for Love Lies Bleeding
#
# Fetching IMDb data for: The Zone of Interest (2024)
# Starting search for: The Zone of Interest (2024)
# Search URL: https://www.imdb.com/find?q=The+Zone+of+Interest+2024
# Search page fetched successfully for The Zone of Interest
# Navigated to movie page URL: https://www.imdb.com/title/tt32631879/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Zone of Interest
# Rating not found for The Zone of Interest
# Director found: Robert Szanto
# Budget found: $1,000 (estimated)
#
# Fetching IMDb data for: Spy x Family Code: White (2024)
# Starting search for: Spy x Family Code: White (2024)
# Search URL: https://www.imdb.com/find?q=Spy+x+Family+Code:+White+2024
# Search page fetched successfully for Spy x Family Code: White
# Navigated to movie page URL: https://www.imdb.com/title/tt33467786/?ref_=fn_al_tt_1
# Movie page fetched successfully for Spy x Family Code: White
# Rating not found for Spy x Family Code: White
# Director not found for Spy x Family Code: White
# Budget not found for Spy x Family Code: White
#
# Fetching IMDb data for: Ferrari (2024)
# Starting search for: Ferrari (2024)
# Search URL: https://www.imdb.com/find?q=Ferrari+2024
# Search page fetched successfully for Ferrari
# Navigated to movie page URL: https://www.imdb.com/title/tt33706979/?ref_=fn_al_tt_1
# Movie page fetched successfully for Ferrari
# Rating not found for Ferrari
# Director found: Ylenia Politano
# Budget found: €1,500 (estimated)
#
# Fetching IMDb data for: The Chosen: S4 Episodes 7-8 (2024)
# Starting search for: The Chosen: S4 Episodes 7-8 (2024)
# Search URL: https://www.imdb.com/find?q=The+Chosen:+S4+Episodes+7-8+2024
# Search page fetched successfully for The Chosen: S4 Episodes 7-8
# Navigated to movie page URL: https://www.imdb.com/title/tt34480026/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Chosen: S4 Episodes 7-8
# Rating not found for The Chosen: S4 Episodes 7-8
# Director not found for The Chosen: S4 Episodes 7-8
# Budget not found for The Chosen: S4 Episodes 7-8
#
# Fetching IMDb data for: Megalopolis (2024)
# Starting search for: Megalopolis (2024)
# Search URL: https://www.imdb.com/find?q=Megalopolis+2024
# Search page fetched successfully for Megalopolis
# Navigated to movie page URL: https://www.imdb.com/title/tt10128846/?ref_=fn_al_tt_1
# Movie page fetched successfully for Megalopolis
# Rating found: 4.8
# Director found: Francis Ford Coppola
# Budget found: $120,000,000 (estimated)
#
# Fetching IMDb data for: Sight (2024)
# Starting search for: Sight (2024)
# Search URL: https://www.imdb.com/find?q=Sight+2024
# Search page fetched successfully for Sight
# Navigated to movie page URL: https://www.imdb.com/title/tt30487848/?ref_=fn_al_tt_1
# Movie page fetched successfully for Sight
# Rating found: 6.1
# Director found: Karen Troubetzkoy
# Budget not found for Sight
#
# Fetching IMDb data for: Haikyu!! The Dumpster Battle (2024)
# Starting search for: Haikyu!! The Dumpster Battle (2024)
# Search URL: https://www.imdb.com/find?q=Haikyu!!+The+Dumpster+Battle+2024
# Search page fetched successfully for Haikyu!! The Dumpster Battle
# Navigated to movie page URL: https://www.imdb.com/title/tt30476486/?ref_=fn_al_tt_1
# Movie page fetched successfully for Haikyu!! The Dumpster Battle
# Rating found: 7.8
# Director found: Susumu Mitsunaka
# Budget not found for Haikyu!! The Dumpster Battle
#
# Fetching IMDb data for: Afraid (2024)
# Starting search for: Afraid (2024)
# Search URL: https://www.imdb.com/find?q=Afraid+2024
# Search page fetched successfully for Afraid
# Navigated to movie page URL: https://www.imdb.com/title/tt24577462/?ref_=fn_al_tt_1
# Movie page fetched successfully for Afraid
# Rating found: 5.1
# Director found: Chris Weitz
# Budget found: $12,000,000 (estimated)
#
# Fetching IMDb data for: The Hunger Games: The Ballad of Songbirds & Snakes (2024)
# Starting search for: The Hunger Games: The Ballad of Songbirds & Snakes (2024)
# Search URL: https://www.imdb.com/find?q=The+Hunger+Games:+The+Ballad+of+Songbirds+&+Snakes+2024
# Search page fetched successfully for The Hunger Games: The Ballad of Songbirds & Snakes
# Navigated to movie page URL: https://www.imdb.com/title/tt10545296/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Hunger Games: The Ballad of Songbirds & Snakes
# Rating found: 6.7
# Director found: Francis Lawrence
# Budget found: $100,000,000 (estimated)
#
# Fetching IMDb data for: I.S.S. (2024)
# Starting search for: I.S.S. (2024)
# Search URL: https://www.imdb.com/find?q=I.S.S.+2024
# Search page fetched successfully for I.S.S.
# Navigated to movie page URL: https://www.imdb.com/title/tt32351030/?ref_=fn_al_tt_1
# Movie page fetched successfully for I.S.S.
# Rating not found for I.S.S.
# Director found: Sumaiyya Buksh
# Budget not found for I.S.S.
#
# Fetching IMDb data for: Cuckoo (2024)
# Starting search for: Cuckoo (2024)
# Search URL: https://www.imdb.com/find?q=Cuckoo+2024
# Search page fetched successfully for Cuckoo
# Navigated to movie page URL: https://www.imdb.com/title/tt12349832/?ref_=fn_al_tt_1
# Movie page fetched successfully for Cuckoo
# Rating found: 5.8
# Director found: Tilman Singer
# Budget found: $7,000,000 (estimated)
#
# Fetching IMDb data for: Back to Black (2024)
# Starting search for: Back to Black (2024)
# Search URL: https://www.imdb.com/find?q=Back+to+Black+2024
# Search page fetched successfully for Back to Black
# Navigated to movie page URL: https://www.imdb.com/title/tt21261712/?ref_=fn_al_tt_1
# Movie page fetched successfully for Back to Black
# Rating found: 6.3
# Director found: Sam Taylor-Johnson
# Budget found: $30,000,000 (estimated)
#
# Fetching IMDb data for: The Book of Clarence (2024)
# Starting search for: The Book of Clarence (2024)
# Search URL: https://www.imdb.com/find?q=The+Book+of+Clarence+2024
# Search page fetched successfully for The Book of Clarence
# Navigated to movie page URL: https://www.imdb.com/title/tt31042716/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Book of Clarence
# Rating not found for The Book of Clarence
# Director not found for The Book of Clarence
# Budget not found for The Book of Clarence
#
# Fetching IMDb data for: The Nightmare Before Christmas2024 Re-release (2024)
# Starting search for: The Nightmare Before Christmas2024 Re-release (2024)
# Search URL: https://www.imdb.com/find?q=The+Nightmare+Before+Christmas2024+Re-release+2024
# Search page fetched successfully for The Nightmare Before Christmas2024 Re-release
# No search results found for The Nightmare Before Christmas2024 Re-release
#
# Fetching IMDb data for: Columbia 100th Anniversary SeriesColumbia 100th Anniversary Series (2024)
# Starting search for: Columbia 100th Anniversary SeriesColumbia 100th Anniversary Series (2024)
# Search URL: https://www.imdb.com/find?q=Columbia+100th+Anniversary+SeriesColumbia+100th+Anniversary+Series+2024
# Search page fetched successfully for Columbia 100th Anniversary SeriesColumbia 100th Anniversary Series
# No search results found for Columbia 100th Anniversary SeriesColumbia 100th Anniversary Series
#
# Fetching IMDb data for: Someone Like You (2024)
# Starting search for: Someone Like You (2024)
# Search URL: https://www.imdb.com/find?q=Someone+Like+You+2024
# Search page fetched successfully for Someone Like You
# ...
# Search page fetched successfully for Girl, Interrupted
# Navigated to movie page URL: https://www.imdb.com/title/tt0172493/?ref_=fn_al_tt_1
# Movie page fetched successfully for Girl, Interrupted
# Rating found: 7.3
# Director found: James Mangold
# Budget found: $40,000,000 (estimated)
#
# Fetching IMDb data for: Love & Basketball (2000)
# Starting search for: Love & Basketball (2000)
# Search URL: https://www.imdb.com/find?q=Love+&+Basketball+2000
# Search page fetched successfully for Love & Basketball
# Navigated to movie page URL: https://www.imdb.com/name/nm0001349/?ref_=fn_al_nm_1
# Movie page fetched successfully for Love & Basketball
# Rating not found for Love & Basketball
# Director found: Contact info
# Budget not found for Love & Basketball
#
# Fetching IMDb data for: High Fidelity (2000)
# Starting search for: High Fidelity (2000)
# Search URL: https://www.imdb.com/find?q=High+Fidelity+2000
# Search page fetched successfully for High Fidelity
# Navigated to movie page URL: https://www.imdb.com/title/tt0146882/?ref_=fn_al_tt_1
# Movie page fetched successfully for High Fidelity
# Rating found: 7.4
# Director found: Stephen Frears
# Budget found: $30,000,000 (estimated)
#
# Fetching IMDb data for: Book of Shadows: Blair Witch 2 (2000)
# Starting search for: Book of Shadows: Blair Witch 2 (2000)
# Search URL: https://www.imdb.com/find?q=Book+of+Shadows:+Blair+Witch+2+2000
# Search page fetched successfully for Book of Shadows: Blair Witch 2
# Navigated to movie page URL: https://www.imdb.com/title/tt0229260/?ref_=fn_al_tt_1
# Movie page fetched successfully for Book of Shadows: Blair Witch 2
# Rating found: 4.0
# Director found: Joe Berlinger
# Budget found: $15,000,000 (estimated)
#
# Fetching IMDb data for: Proof of Life (2000)
# Starting search for: Proof of Life (2000)
# Search URL: https://www.imdb.com/find?q=Proof+of+Life+2000
# Search page fetched successfully for Proof of Life
# Navigated to movie page URL: https://www.imdb.com/title/tt0228750/?ref_=fn_al_tt_1
# Movie page fetched successfully for Proof of Life
# Rating found: 6.3
# Director found: Taylor Hackford
# Budget found: $65,000,000 (estimated)
#
# Fetching IMDb data for: The Adventures of Rocky & Bullwinkle (2000)
# Starting search for: The Adventures of Rocky & Bullwinkle (2000)
# Search URL: https://www.imdb.com/find?q=The+Adventures+of+Rocky+&+Bullwinkle+2000
# Search page fetched successfully for The Adventures of Rocky & Bullwinkle
# Navigated to movie page URL: https://www.imdb.com/title/tt0131704/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Adventures of Rocky & Bullwinkle
# Rating found: 4.3
# Director found: Des McAnuff
# Budget found: $76,000,000 (estimated)
#
# Fetching IMDb data for: Nurse Betty (2000)
# Starting search for: Nurse Betty (2000)
# Search URL: https://www.imdb.com/find?q=Nurse+Betty+2000
# Search page fetched successfully for Nurse Betty
# Navigated to movie page URL: https://www.imdb.com/title/tt0171580/?ref_=fn_al_tt_1
# Movie page fetched successfully for Nurse Betty
# Rating found: 6.3
# Director found: Neil LaBute
# Budget found: $35,000,000 (estimated)
#
# Fetching IMDb data for: Bicentennial Man (2000)
# Starting search for: Bicentennial Man (2000)
# Search URL: https://www.imdb.com/find?q=Bicentennial+Man+2000
# Search page fetched successfully for Bicentennial Man
# Navigated to movie page URL: https://www.imdb.com/title/tt0182789/?ref_=fn_al_tt_1
# Movie page fetched successfully for Bicentennial Man
# Rating found: 6.9
# Director found: Chris Columbus
# Budget found: $100,000,000 (estimated)
#
# Fetching IMDb data for: Deuce Bigalow: Male Gigolo (2000)
# Starting search for: Deuce Bigalow: Male Gigolo (2000)
# Search URL: https://www.imdb.com/find?q=Deuce+Bigalow:+Male+Gigolo+2000
# Search page fetched successfully for Deuce Bigalow: Male Gigolo
# Navigated to movie page URL: https://www.imdb.com/title/tt0205000/?ref_=fn_al_tt_1
# Movie page fetched successfully for Deuce Bigalow: Male Gigolo
# Rating found: 5.7
# Director found: Mike Mitchell
# Budget found: $17,000,000 (estimated)
#
# Fetching IMDb data for: Reindeer Games (2000)
# Starting search for: Reindeer Games (2000)
# Search URL: https://www.imdb.com/find?q=Reindeer+Games+2000
# Search page fetched successfully for Reindeer Games
# Navigated to movie page URL: https://www.imdb.com/title/tt0184858/?ref_=fn_al_tt_1
# Movie page fetched successfully for Reindeer Games
# Rating found: 5.8
# Director found: John Frankenheimer
# Budget found: $42,000,000 (estimated)
#
# Fetching IMDb data for: Titan A.E. (2000)
# Starting search for: Titan A.E. (2000)
# Search URL: https://www.imdb.com/find?q=Titan+A.E.+2000
# Search page fetched successfully for Titan A.E.
# Navigated to movie page URL: https://www.imdb.com/title/tt0120913/?ref_=fn_al_tt_1
# Movie page fetched successfully for Titan A.E.
# Rating found: 6.6
# Director found: Don Bluth
# Budget found: $75,000,000 (estimated)
#
# Fetching IMDb data for: Boys and Girls (2000)
# Starting search for: Boys and Girls (2000)
# Search URL: https://www.imdb.com/find?q=Boys+and+Girls+2000
# Search page fetched successfully for Boys and Girls
# Navigated to movie page URL: https://www.imdb.com/title/tt0204175/?ref_=fn_al_tt_1
# Movie page fetched successfully for Boys and Girls
# Rating found: 5.4
# Director found: Robert Iscove
# Budget found: $35,000,000 (estimated)
#
# Fetching IMDb data for: Magnolia (2000)
# Starting search for: Magnolia (2000)
# Search URL: https://www.imdb.com/find?q=Magnolia+2000
# Search page fetched successfully for Magnolia
# Navigated to movie page URL: https://www.imdb.com/title/tt0358205/?ref_=fn_al_tt_1
# Movie page fetched successfully for Magnolia
# Rating found: 7.6
# Director found: Mark Rance
# Budget not found for Magnolia
#
# Fetching IMDb data for: Battlefield Earth (2000)
# Starting search for: Battlefield Earth (2000)
# Search URL: https://www.imdb.com/find?q=Battlefield+Earth+2000
# Search page fetched successfully for Battlefield Earth
# Navigated to movie page URL: https://www.imdb.com/title/tt0185183/?ref_=fn_al_tt_1
# Movie page fetched successfully for Battlefield Earth
# Rating found: 2.5
# Director found: Roger Christian
# Budget found: $73,000,000 (estimated)
#
# Fetching IMDb data for: Urban Legends: Final Cut (2000)
# Starting search for: Urban Legends: Final Cut (2000)
# Search URL: https://www.imdb.com/find?q=Urban+Legends:+Final+Cut+2000
# Search page fetched successfully for Urban Legends: Final Cut
# Navigated to movie page URL: https://www.imdb.com/title/tt0192731/?ref_=fn_al_tt_1
# Movie page fetched successfully for Urban Legends: Final Cut
# Rating found: 4.4
# Director found: John Ottman
# Budget found: $14,000,000 (estimated)
#
# Fetching IMDb data for: Down to You (2000)
# Starting search for: Down to You (2000)
# Search URL: https://www.imdb.com/find?q=Down+to+You+2000
# Search page fetched successfully for Down to You
# Navigated to movie page URL: https://www.imdb.com/title/tt0186975/?ref_=fn_al_tt_1
# Movie page fetched successfully for Down to You
# Rating found: 5.0
# Director found: Kris Isacsson
# Budget found: $11,000,000 (estimated)
#
# Fetching IMDb data for: Wonder Boys (2000)
# Starting search for: Wonder Boys (2000)
# Search URL: https://www.imdb.com/find?q=Wonder+Boys+2000
# Search page fetched successfully for Wonder Boys
# Navigated to movie page URL: https://www.imdb.com/title/tt0185014/?ref_=fn_al_tt_1
# Movie page fetched successfully for Wonder Boys
# Rating found: 7.2
# Director found: Curtis Hanson
# Budget found: $55,000,000 (estimated)
#
# Fetching IMDb data for: Anna and the King (2000)
# Starting search for: Anna and the King (2000)
# Search URL: https://www.imdb.com/find?q=Anna+and+the+King+2000
# Search page fetched successfully for Anna and the King
# Navigated to movie page URL: https://www.imdb.com/title/tt0356362/?ref_=fn_al_tt_1
# Movie page fetched successfully for Anna and the King
# Rating found: 4.5
# Director found: Roddy Lee
# Budget not found for Anna and the King
#
# Fetching IMDb data for: The Ninth Gate (2000)
# Starting search for: The Ninth Gate (2000)
# Search URL: https://www.imdb.com/find?q=The+Ninth+Gate+2000
# Search page fetched successfully for The Ninth Gate
# Navigated to movie page URL: https://www.imdb.com/title/tt0142688/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Ninth Gate
# Rating found: 6.7
# Director found: Roman Polanski
# Budget found: $38,000,000 (estimated)
#
# Fetching IMDb data for: Dracula 2000 (2000)
# Starting search for: Dracula 2000 (2000)
# Search URL: https://www.imdb.com/find?q=Dracula+2000+2000
# Search page fetched successfully for Dracula 2000
# Navigated to movie page URL: https://www.imdb.com/title/tt0219653/?ref_=fn_al_tt_1
# Movie page fetched successfully for Dracula 2000
# Rating found: 4.9
# Director found: Patrick Lussier
# Budget found: $54,000,000 (estimated)
#
# Fetching IMDb data for: The Contender (2000)
# Starting search for: The Contender (2000)
# Search URL: https://www.imdb.com/find?q=The+Contender+2000
# Search page fetched successfully for The Contender
# Navigated to movie page URL: https://www.imdb.com/title/tt0208874/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Contender
# Rating found: 6.9
# Director found: Rod Lurie
# Budget found: $20,000,000 (estimated)
#
# Fetching IMDb data for: The Sixth Sense (2000)
# Starting search for: The Sixth Sense (2000)
# Search URL: https://www.imdb.com/find?q=The+Sixth+Sense+2000
# Search page fetched successfully for The Sixth Sense
# Navigated to movie page URL: https://www.imdb.com/title/tt0167404/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Sixth Sense
# Rating found: 8.2
# Director found: M. Night Shyamalan
# Budget found: $40,000,000 (estimated)
#
# Fetching IMDb data for: Small Time Crooks (2000)
# Starting search for: Small Time Crooks (2000)
# Search URL: https://www.imdb.com/find?q=Small+Time+Crooks+2000
# Search page fetched successfully for Small Time Crooks
# Navigated to movie page URL: https://www.imdb.com/title/tt0196216/?ref_=fn_al_tt_1
# Movie page fetched successfully for Small Time Crooks
# Rating found: 6.7
# Director found: Woody Allen
# Budget found: $25,000,000 (estimated)
#
# Fetching IMDb data for: Red Planet (2000)
# Starting search for: Red Planet (2000)
# Search URL: https://www.imdb.com/find?q=Red+Planet+2000
# Search page fetched successfully for Red Planet
# Navigated to movie page URL: https://www.imdb.com/title/tt0199753/?ref_=fn_al_tt_1
# Movie page fetched successfully for Red Planet
# Rating found: 5.7
# Director found: Antony Hoffman
# Budget found: $80,000,000 (estimated)
#
# Fetching IMDb data for: Center Stage (2000)
# Starting search for: Center Stage (2000)
# Search URL: https://www.imdb.com/find?q=Center+Stage+2000
# Search page fetched successfully for Center Stage
# Navigated to movie page URL: https://www.imdb.com/title/tt0210616/?ref_=fn_al_tt_1
# Movie page fetched successfully for Center Stage
# Rating found: 6.7
# Director found: Nicholas Hytner
# Budget found: $29,000,000 (estimated)
#
# Fetching IMDb data for: Best in Show (2000)
# Starting search for: Best in Show (2000)
# Search URL: https://www.imdb.com/find?q=Best+in+Show+2000
# Search page fetched successfully for Best in Show
# Navigated to movie page URL: https://www.imdb.com/title/tt0218839/?ref_=fn_al_tt_1
# Movie page fetched successfully for Best in Show
# Rating found: 7.5
# Director found: Christopher Guest
# Budget found: $10,000,000 (estimated)
#
# Fetching IMDb data for: Boiler Room (2000)
# Starting search for: Boiler Room (2000)
# Search URL: https://www.imdb.com/find?q=Boiler+Room+2000
# Search page fetched successfully for Boiler Room
# Navigated to movie page URL: https://www.imdb.com/title/tt0181984/?ref_=fn_al_tt_1
# Movie page fetched successfully for Boiler Room
# Rating found: 7.0
# Director found: Ben Younger
# Budget found: $7,000,000 (estimated)
#
# Fetching IMDb data for: Billy Elliot (2000)
# Starting search for: Billy Elliot (2000)
# Search URL: https://www.imdb.com/find?q=Billy+Elliot+2000
# Search page fetched successfully for Billy Elliot
# Navigated to movie page URL: https://www.imdb.com/title/tt0249462/?ref_=fn_al_tt_1
# Movie page fetched successfully for Billy Elliot
# Rating found: 7.7
# Director found: Stephen Daldry
# Budget found: $5,000,000 (estimated)
#
# Fetching IMDb data for: Lost Souls (2000)
# Starting search for: Lost Souls (2000)
# Search URL: https://www.imdb.com/find?q=Lost+Souls+2000
# Search page fetched successfully for Lost Souls
# Navigated to movie page URL: https://www.imdb.com/title/tt0160484/?ref_=fn_al_tt_1
# Movie page fetched successfully for Lost Souls
# Rating found: 4.8
# Director found: Janusz Kaminski
# Budget found: $50,000,000 (estimated)
#
# Fetching IMDb data for: Eye of the Beholder (2000)
# Starting search for: Eye of the Beholder (2000)
# Search URL: https://www.imdb.com/find?q=Eye+of+the+Beholder+2000
# Search page fetched successfully for Eye of the Beholder
# Navigated to movie page URL: https://www.imdb.com/title/tt0509459/?ref_=fn_al_tt_1
# Movie page fetched successfully for Eye of the Beholder
# Rating found: 8.7
# Director found: Peter Fisk
# Budget not found for Eye of the Beholder
#
# Fetching IMDb data for: Thomas and the Magic Railroad (2000)
# Starting search for: Thomas and the Magic Railroad (2000)
# Search URL: https://www.imdb.com/find?q=Thomas+and+the+Magic+Railroad+2000
# Search page fetched successfully for Thomas and the Magic Railroad
# Navigated to movie page URL: https://www.imdb.com/title/tt0205461/?ref_=fn_al_tt_1
# Movie page fetched successfully for Thomas and the Magic Railroad
# Rating found: 4.2
# Director found: Britt Allcroft
# Budget found: $19,000,000 (estimated)
#
# Fetching IMDb data for: Loser (2000)
# Starting search for: Loser (2000)
# Search URL: https://www.imdb.com/find?q=Loser+2000
# Search page fetched successfully for Loser
# Navigated to movie page URL: https://www.imdb.com/title/tt0217630/?ref_=fn_al_tt_1
# Movie page fetched successfully for Loser
# Rating found: 5.3
# Director found: Amy Heckerling
# Budget found: $20,000,000 (estimated)
#
# Fetching IMDb data for: Drowning Mona (2000)
# Starting search for: Drowning Mona (2000)
# Search URL: https://www.imdb.com/find?q=Drowning+Mona+2000
# Search page fetched successfully for Drowning Mona
# Navigated to movie page URL: https://www.imdb.com/title/tt0186045/?ref_=fn_al_tt_1
# Movie page fetched successfully for Drowning Mona
# Rating found: 5.7
# Director found: Nick Gomez
# Budget found: $37,000,000 (estimated)
#
# Fetching IMDb data for: Bait (2000)
# Starting search for: Bait (2000)
# Search URL: https://www.imdb.com/find?q=Bait+2000
# Search page fetched successfully for Bait
# Navigated to movie page URL: https://www.imdb.com/title/tt0211938/?ref_=fn_al_tt_1
# Movie page fetched successfully for Bait
# Rating found: 5.7
# Director found: Antoine Fuqua
# Budget found: $51,000,000 (estimated)
#
# Fetching IMDb data for: American Psycho (2000)
# Starting search for: American Psycho (2000)
# Search URL: https://www.imdb.com/find?q=American+Psycho+2000
# Search page fetched successfully for American Psycho
# Navigated to movie page URL: https://www.imdb.com/title/tt0144084/?ref_=fn_al_tt_1
# Movie page fetched successfully for American Psycho
# Rating found: 7.6
# Director found: Mary Harron
# Budget found: $7,000,000 (estimated)
#
# Fetching IMDb data for: Get Carter (2000)
# Starting search for: Get Carter (2000)
# Search URL: https://www.imdb.com/find?q=Get+Carter+2000
# Search page fetched successfully for Get Carter
# Navigated to movie page URL: https://www.imdb.com/title/tt0208988/?ref_=fn_al_tt_1
# Movie page fetched successfully for Get Carter
# Rating found: 5.2
# Director found: Stephen Kay
# Budget found: $63,600,000 (estimated)
#
# Fetching IMDb data for: The Next Best Thing (2000)
# Starting search for: The Next Best Thing (2000)
# Search URL: https://www.imdb.com/find?q=The+Next+Best+Thing+2000
# Search page fetched successfully for The Next Best Thing
# Navigated to movie page URL: https://www.imdb.com/title/tt0156841/?ref_=fn_al_tt_1
# Movie page fetched successfully for The Next Best Thing
# Rating found: 4.7
# Director found: John Schlesinger
# Budget found: $25,000,000 (estimated)
#
# Fetching IMDb data for: Man on the Moon (2000)
# Starting search for: Man on the Moon (2000)
# Search URL: https://www.imdb.com/find?q=Man+on+the+Moon+2000
# Search page fetched successfully for Man on the Moon
# Navigated to movie page URL: https://www.imdb.com/title/tt0365477/?ref_=fn_al_tt_1
